# %% [markdown]
# # insertion sort
# remember card example to remeber, we do not swap the values in insertion sort, rather we shift the values wrt a paticular
#
# algo
# start at index 1-> check if it is at right place-> yes then move to next rount
#                                                 -> no then find the appropriate index and move the elenemtn to right of this index to make room to occupiy the current index
# -> do this till all n-1 elenemnts
#
#
# Why.?
# adaptable algorithm -> while finding index to shift elenment, we dont have to traverse the enitre sorted array, we just have to find index where we have to keep the current elenemtn i.e ith elenment
#
# stable algorithm ->
#
# Tc  = O(n^2)
# Sc = O(1)
#
# best case time complexity - o(n)
# worse case time complexity - o(n^2)

# %%
def insertion_sort(arr):
    for i in range(1,len(arr)-1):
        temp = arr[i]
        j=0
        for j in range(i-1,0,-1):
            #elenemt shifting
            if arr[j]>temp:
                # shifting the elenments
                pass
            else:
                break
        arr[j+1] = temp
